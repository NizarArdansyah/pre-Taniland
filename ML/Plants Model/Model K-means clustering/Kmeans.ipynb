# %% [markdown]
# <a href="https://colab.research.google.com/github/NizarArdansyah/Capstone-Project-Machine-Learning/blob/main/Kmeans%20plants%20recomendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualisasi
import matplotlib.pyplot as plt 
from sklearn.preprocessing import MinMaxScaler
import csv
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# Informasi Dataset

# %%
df = pd.read_csv('Crop_recommendation.csv')

df.head()
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2100.000000  2100.000000  2100.000000  2100.000000  2100.000000
# mean     49.225714    53.672381    48.537619    25.647571    71.093299
# std      37.194613    33.695004    51.803317     5.174487    22.683467
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      20.000000    27.000000    20.000000    22.602437    59.237124
# 50%      36.000000    52.000000    30.000000    25.667383    80.532760
# 75%      84.000000    69.000000    50.000000    28.684566    90.194600
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2100.000000  2100.000000
# mean      6.456942   100.067030
# std       0.784002    53.848519
# min       3.504752    20.211267
# 25%       5.948298    63.489314
# 50%       6.414227    91.978786
# 75%       6.910487   117.368990
# max       9.935091   298.560117

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of         N   P   K  temperature   humidity        ph    rainfall label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536  padi
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537  padi
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248  padi
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034  padi
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340  padi
# ...   ...  ..  ..          ...        ...       ...         ...   ...
# 2095  107  34  32    26.774637  66.413269  6.780064  177.774507  kopi
# 2096   99  15  27    27.417112  56.636362  6.086922  127.924610  kopi
# 2097  118  33  30    24.131797  67.225123  6.362608  173.322839  kopi
# 2098  117  32  34    26.272418  52.127394  6.758793  127.175293  kopi
# 2099  104  18  30    23.603016  60.396475  6.779833  140.937041  kopi
#
# [2100 rows x 8 columns]>

# %%
df.info
# Out:
# <bound method DataFrame.info of         N   P   K  temperature   humidity        ph    rainfall label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536  padi
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537  padi
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248  padi
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034  padi
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340  padi
# ...   ...  ..  ..          ...        ...       ...         ...   ...
# 2095  107  34  32    26.774637  66.413269  6.780064  177.774507  kopi
# 2096   99  15  27    27.417112  56.636362  6.086922  127.924610  kopi
# 2097  118  33  30    24.131797  67.225123  6.362608  173.322839  kopi
# 2098  117  32  34    26.272418  52.127394  6.758793  127.175293  kopi
# 2099  104  18  30    23.603016  60.396475  6.779833  140.937041  kopi
#
# [2100 rows x 8 columns]>

# %%
# df = df.drop(['N','P','K','rainfall','ph'], axis=1)

# %%
import math

# Memperbarui kolom "temperature" dan "humidity" dengan nilai bulat ke atas
df['temperature'] = df['temperature'].apply(math.ceil).astype(int)
df['humidity'] = df['humidity'].apply(math.ceil).astype(int)

# Menampilkan dataframe setelah pembulatan nilai
print(df)
# Out:
#         N   P   K  temperature  humidity        ph    rainfall label
# 0      90  42  43           21        83  6.502985  202.935536  padi
# 1      85  58  41           22        81  7.038096  226.655537  padi
# 2      60  55  44           24        83  7.840207  263.964248  padi
# 3      74  35  40           27        81  6.980401  242.864034  padi
# 4      78  42  42           21        82  7.628473  262.717340  padi
# ...   ...  ..  ..          ...       ...       ...         ...   ...
# 2095  107  34  32           27        67  6.780064  177.774507  kopi
# 2096   99  15  27           28        57  6.086922  127.924610  kopi
# 2097  118  33  30           25        68  6.362608  173.322839  kopi
# 2098  117  32  34           27        53  6.758793  127.175293  kopi
# 2099  104  18  30           24        61  6.779833  140.937041  kopi
#
# [2100 rows x 8 columns]

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['temperature'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['temperature'])
plt.show()

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['humidity'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['humidity'])
plt.show()

# %%
sns.boxplot(x=df['temperature'])
# Out:
# <Axes: xlabel='temperature'>

# %%
sns.boxplot(x=df['humidity'])
# Out:
# <Axes: xlabel='humidity'>

# %%
Q1 = df['temperature'].quantile(0.25)
Q3 = df['temperature'].quantile(0.75)
IQR = Q3 - Q1
boxplot_min = Q1 - 1.5 * IQR
boxplot_max = Q3 + 1.5 * IQR
print('Q1:\n',Q1)
print('\nQ3:\n',Q3)
print('\nIQR:\n',IQR)
print('\nMin:\n',boxplot_min)
print('\nMax:\n',boxplot_max)
# Out:
# Q1:
#  23.0
#
# Q3:
#  29.0
#
# IQR:
#  6.0
#
# Min:
#  14.0
#
# Max:
#  38.0

# %%
filter_min = df['temperature']<boxplot_min
filter_max = df['temperature']>boxplot_max
data_df = df[~(filter_min|filter_max)] 
data_df.shape
# Out:
# (2024, 8)

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=data_df['temperature'])

# %%
data_df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
# backup dataframe for encoding
data_df.to_csv('data_df.csv')
df_clean = data_df.copy()

# %%
df_clean.value_counts()
# Out:
# N    P    K    temperature  humidity  ph        rainfall    label
# 0    5    36   25           91        6.152907  105.529185  delima    1
# 65   62   51   32           91        6.511625  207.073512  pepaya    1
# 67   58   39   26           81        5.453592  220.115671  padi      1
#      51   24   24           62        5.584171  64.777914   jagung    1
#      47   44   27           82        7.868475  280.404439  padi      1
#                                                                      ..
# 25   143  198  23           92        6.027314  107.855225  apel      1
#      132  198  23           91        5.732758  100.117344  apel      1
#      129  195  18           82        5.777271  72.371277   anggur    1
#      121  201  31           83        5.594241  70.082004   anggur    1
# 140  45   15   26           81        5.801048  99.395572   kapas     1
# Length: 2024, dtype: int64

# %%
df_clean.tail()
# Out:
#         N   P   K  temperature  humidity        ph    rainfall label
# 2095  107  34  32           27        67  6.780064  177.774507  kopi
# 2096   99  15  27           28        57  6.086922  127.924610  kopi
# 2097  118  33  30           25        68  6.362608  173.322839  kopi
# 2098  117  32  34           27        53  6.758793  127.175293  kopi
# 2099  104  18  30           24        61  6.779833  140.937041  kopi

# %%
for feat in df_clean.columns:
    hh = df_clean.groupby(feat)['label'].count()
    print(feat,',', 'Unique :',len(df_clean[feat].unique()))
# Out:
# N , Unique : 137
# P , Unique : 117
# K , Unique : 73
# temperature , Unique : 25
# humidity , Unique : 81
# ph , Unique : 2024
# rainfall , Unique : 2024
# label , Unique : 21

# %%
df_clean['label'].value_counts().plot.bar()
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df_clean[[ 'temperature', 'humidity']])

# %%
#pip install imbalanced-learn scikit-learn

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import pandas as pd


# Menampilkan jumlah sampel sebelum SMOTE
print("Jumlah sampel sebelum SMOTE:")
print(df_clean['label'].value_counts())
print("=============================")

# Memisahkan fitur dan target
X = df_clean[['temperature', 'humidity']]
y = df_clean['label']

# Menerapkan SMOTE
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

# Membentuk dataset baru setelah SMOTE
# Membuat dataset baru setelah SMOTE
df_resampled = pd.DataFrame(X_res, columns=['temperature', 'humidity'])
df_resampled['label'] = y_res

# Menampilkan jumlah sampel setelah SMOTE
print("\nJumlah sampel setelah SMOTE:")
print(y_res.value_counts())
# Out:
# Jumlah sampel sebelum SMOTE:
# padi              100
# delima            100
# kapas             100
# kelapa            100
# apel              100
# melon             100
# semangka          100
# mangga            100
# jagung            100
# pisang            100
# lentil            100
# lentil hitam      100
# kacang hijau      100
# kacang panjang    100
# kacang polong     100
# kacang merah      100
# buncis            100
# kopi              100
# jeruk              87
# anggur             70
# pepaya             67
# Name: label, dtype: int64
# =============================
#
# Jumlah sampel setelah SMOTE:
# padi              100
# mangga            100
# kapas             100
# kelapa            100
# pepaya            100
# jeruk             100
# apel              100
# melon             100
# semangka          100
# anggur            100
# pisang            100
# jagung            100
# delima            100
# lentil            100
# lentil hitam      100
# kacang hijau      100
# kacang panjang    100
# kacang polong     100
# kacang merah      100
# buncis            100
# kopi              100
# Name: label, dtype: int64

# %% [markdown]
# Eksplorasi data menentukan korelasi terbaik

# %%
sns.pairplot(df_resampled)

# %%
plt.figure(1 , figsize = (15 , 6))
n = 0 
for x in ['humidity' , 'temperature' ]:
    n += 1
    plt.subplot(1 , 3 , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    sns.distplot(df_resampled[x] , bins = 15)
    plt.title('Distplot of {}'.format(x))
plt.show()
# Out:
# <ipython-input-25-434b2e8f63db>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_resampled[x] , bins = 15)
# <ipython-input-25-434b2e8f63db>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_resampled[x] , bins = 15)

# %%
sns.pairplot(df_resampled, vars = ['temperature', 'humidity'], hue = "label")

# %%
df_resampled.corr()
# Out:
# <ipython-input-27-0d06f5513b6a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_resampled.corr()
#              temperature  humidity
# temperature      1.00000   0.21398
# humidity         0.21398   1.00000

# %%
sns.heatmap(df_resampled.corr());
# Out:
# <ipython-input-28-cbede33d5c4a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_resampled.corr());

# %% [markdown]
# Normalisasi data

# %%
# data_array=[]

# # Baca file CSV dan masukkan data ke dalam array
# with open('Crop_recommendation.csv', 'r') as file:
#     reader = csv.reader(file)
#     next(reader)  # Skip header baris pertama jika ada
#     for row in reader:
#         data_array.append(row[:6])

# # Konversi array menjadi numpy array untuk kemudahan pengolahan data
# data_array = np.array(data_array)

# # Inisialisasi objek MinMaxScaler
# scaler = MinMaxScaler()

# # Normalisasi data tanaman
# data_tanaman_normal = scaler.fit_transform(data_array)

# print("Data Tanaman:")
# print(data_array)
# print("\nData Tanaman Setelah Normalisasi:")
# print(data_tanaman_normal)
# print("=======================")
# print(data_tanaman_normal[:10])
# print(data_tanaman_normal.shape)
# print(data_array.shape)

# %%
# Mendapatkan kolom temperature sebagai data x
x = df_resampled[['temperature']]

# Mendapatkan kolom humidity sebagai data y
y = df_resampled[['humidity']]

# Membuat scatter plot
plt.scatter(x, y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot Sebelum Dinormalisasi')

# Menampilkan plot
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=10)

print('training dataset:')
print(X_train.shape)
print(y_train.shape)
print()
print('testing dataset:')
print(X_test.shape)
print(y_test.shape)
# Out:
# training dataset:
# (1680, 2)
# (1680,)
#
# testing dataset:
# (420, 2)
# (420,)

# %% [markdown]
# **Kmeans Model**
#
# Menentukan Jumlah Cluster dengan metode silhouette_scores

# %%
df_resampled = df_resampled.drop(['label'],axis=1)

# %%
# Menyimpan skor siluet untuk setiap jumlah kluster
silhouette_scores = []

# K range untuk percobaan jumlah kluster
k_range = range(2, 10)

# Melakukan klasterisasi dan menghitung skor siluet untuk setiap jumlah kluster
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_resampled)
    labels = kmeans.labels_
    score = silhouette_score(df_resampled, labels)
    silhouette_scores.append(score)

# Plot silhouette scores
plt.plot(k_range, silhouette_scores, 'bx-')
plt.xlabel('Jumlah Kluster')
plt.ylabel('Silhouette Score')
plt.title('Metode Silhouette Score untuk Menentukan Jumlah Kluster Optimal')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Menentukan Jumlah Cluster dengan metode Elbow

# %%
# Menyimpan nilai inersia untuk setiap jumlah kluster
inertia = []

# K range untuk percobaan jumlah kluster
k_range = range(1, 10)

# Melakukan klasterisasi untuk setiap jumlah kluster
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_resampled)
    inertia.append(kmeans.inertia_)

# Plot elbow curve
plt.plot(k_range, inertia, 'bx-')
plt.xlabel('Jumlah Kluster')
plt.ylabel('Inersia')
plt.title('Metode Elbow untuk Menentukan Jumlah Kluster Optimal')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Membuat model K-Means

# %%
# Jumlah kluster yang diinginkan
n_clusters = 3

# Inisialisasi model K-means
kmeans = KMeans(n_clusters=n_clusters, random_state=42)

# Melatih model dengan data tanaman
kmeans.fit(X_res)


# Menggambarkan pusat-pusat kluster
centers = kmeans.cluster_centers_

# Prediksi kluster untuk data tanaman
labels = kmeans.labels_


# Cetak pusat-pusat kluster
print("Pusat-Pusat Kluster:")
print(centers)

# Cetak kluster untuk setiap data tanaman
print("\nKluster untuk Setiap Data Tanaman:")
for i, label in enumerate(labels):
    print(f"Data {i+1}: Kluster {label+1}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Pusat-Pusat Kluster:
# [[27.61052632 59.14285714]
#  [26.11092715 87.83278146]
#  [20.96035242 21.57709251]]
#
# Kluster untuk Setiap Data Tanaman:
# Data 1: Kluster 2
# Data 2: Kluster 2
# Data 3: Kluster 2
# Data 4: Kluster 2
# Data 5: Kluster 2
# Data 6: Kluster 2
# Data 7: Kluster 2
# Data 8: Kluster 2
# Data 9: Kluster 2
# Data 10: Kluster 2
# Data 11: Kluster 2
# Data 12: Kluster 2
# Data 13: Kluster 2
# Data 14: Kluster 2
# Data 15: Kluster 2
# Data 16: Kluster 2
# Data 17: Kluster 2
# Data 18: Kluster 2
# Data 19: Kluster 2
# Data 20: Kluster 2
# Data 21: Kluster 2
# Data 22: Kluster 2
# Data 23: Kluster 2
# Data 24: Kluster 2
# Data 25: Kluster 2
# Data 26: Kluster 2
# Data 27: Kluster 2
# Data 28: Kluster 2
# Data 29: Kluster 2
# Data 30: Kluster 2
# Data 31: Kluster 2
# Data 32: Kluster 2
# Data 33: Kluster 2
# Data 34: Kluster 2
# Data 35: Kluster 2
# Data 36: Kluster 2
# Data 37: Kluster 2
# Data 38: Kluster 2
# Data 39: Kluster 2
# Data 40: Kluster 2
# Data 41: Kluster 2
# Data 42: Kluster 2
# Data 43: Kluster 2
# Data 44: Kluster 2
# Data 45: Kluster 2
# Data 46: Kluster 2
# Data 47: Kluster 2
# Data 48: Kluster 2
# Data 49: Kluster 2
# Data 50: Kluster 2
# Data 51: Kluster 2
# Data 52: Kluster 2
# Data 53: Kluster 2
# Data 54: Kluster 2
# Data 55: Kluster 2
# Data 56: Kluster 2
# Data 57: Kluster 2
# Data 58: Kluster 2
# Data 59: Kluster 2
# Data 60: Kluster 2
# Data 61: Kluster 2
# Data 62: Kluster 2
# Data 63: Kluster 2
# Data 64: Kluster 2
# Data 65: Kluster 2
# Data 66: Kluster 2
# Data 67: Kluster 2
# Data 68: Kluster 2
# Data 69: Kluster 2
# Data 70: Kluster 2
# Data 71: Kluster 2
# Data 72: Kluster 2
# Data 73: Kluster 2
# Data 74: Kluster 2
# Data 75: Kluster 2
# Data 76: Kluster 2
# Data 77: Kluster 2
# Data 78: Kluster 2
# Data 79: Kluster 2
# Data 80: Kluster 2
# Data 81: Kluster 2
# Data 82: Kluster 2
# Data 83: Kluster 2
# Data 84: Kluster 2
# Data 85: Kluster 2
# Data 86: Kluster 2
# Data 87: Kluster 2
# Data 88: Kluster 2
# Data 89: Kluster 2
# Data 90: Kluster 2
# Data 91: Kluster 2
# Data 92: Kluster 2
# Data 93: Kluster 2
# Data 94: Kluster 2
# Data 95: Kluster 2
# Data 96: Kluster 2
# Data 97: Kluster 2
# Data 98: Kluster 2
# Data 99: Kluster 2
# Data 100: Kluster 2
# Data 101: Kluster 1
# Data 102: Kluster 1
# Data 103: Kluster 1
# Data 104: Kluster 1
# Data 105: Kluster 1
# Data 106: Kluster 1
# Data 107: Kluster 1
# Data 108: Kluster 1
# Data 109: Kluster 1
# Data 110: Kluster 1
# Data 111: Kluster 2
# Data 112: Kluster 1
# Data 113: Kluster 1
# Data 114: Kluster 1
# Data 115: Kluster 1
# Data 116: Kluster 1
# Data 117: Kluster 1
# Data 118: Kluster 1
# Data 119: Kluster 1
# Data 120: Kluster 1
# Data 121: Kluster 2
# Data 122: Kluster 1
# Data 123: Kluster 1
# Data 124: Kluster 1
# Data 125: Kluster 1
# Data 126: Kluster 1
# Data 127: Kluster 1
# Data 128: Kluster 1
# Data 129: Kluster 1
# Data 130: Kluster 1
# Data 131: Kluster 1
# Data 132: Kluster 1
# Data 133: Kluster 1
# Data 134: Kluster 1
# Data 135: Kluster 1
# Data 136: Kluster 2
# Data 137: Kluster 1
# Data 138: Kluster 1
# Data 139: Kluster 2
# Data 140: Kluster 2
# Data 141: Kluster 2
# Data 142: Kluster 1
# Data 143: Kluster 1
# Data 144: Kluster 1
# Data 145: Kluster 1
# Data 146: Kluster 1
# Data 147: Kluster 1
# Data 148: Kluster 1
# Data 149: Kluster 1
# Data 150: Kluster 1
# Data 151: Kluster 1
# Data 152: Kluster 1
# Data 153: Kluster 1
# Data 154: Kluster 1
# Data 155: Kluster 1
# Data 156: Kluster 1
# Data 157: Kluster 1
# Data 158: Kluster 1
# Data 159: Kluster 1
# Data 160: Kluster 1
# Data 161: Kluster 1
# Data 162: Kluster 1
# Data 163: Kluster 1
# Data 164: Kluster 1
# Data 165: Kluster 1
# Data 166: Kluster 1
# Data 167: Kluster 1
# Data 168: Kluster 2
# Data 169: Kluster 1
# Data 170: Kluster 1
# Data 171: Kluster 1
# Data 172: Kluster 1
# Data 173: Kluster 1
# Data 174: Kluster 2
# Data 175: Kluster 1
# Data 176: Kluster 1
# Data 177: Kluster 1
# Data 178: Kluster 1
# Data 179: Kluster 1
# Data 180: Kluster 1
# Data 181: Kluster 1
# Data 182: Kluster 1
# Data 183: Kluster 1
# Data 184: Kluster 1
# Data 185: Kluster 1
# Data 186: Kluster 1
# Data 187: Kluster 1
# Data 188: Kluster 1
# Data 189: Kluster 1
# Data 190: Kluster 1
# Data 191: Kluster 1
# Data 192: Kluster 1
# Data 193: Kluster 1
# Data 194: Kluster 1
# Data 195: Kluster 1
# Data 196: Kluster 1
# Data 197: Kluster 1
# Data 198: Kluster 1
# Data 199: Kluster 1
# Data 200: Kluster 1
# Data 201: Kluster 3
# Data 202: Kluster 3
# Data 203: Kluster 3
# Data 204: Kluster 3
# Data 205: Kluster 3
# Data 206: Kluster 3
# Data 207: Kluster 3
# Data 208: Kluster 3
# Data 209: Kluster 3
# Data 210: Kluster 3
# Data 211: Kluster 3
# Data 212: Kluster 3
# Data 213: Kluster 3
# Data 214: Kluster 3
# Data 215: Kluster 3
# Data 216: Kluster 3
# Data 217: Kluster 3
# Data 218: Kluster 3
# Data 219: Kluster 3
# Data 220: Kluster 3
# Data 221: Kluster 3
# Data 222: Kluster 3
# Data 223: Kluster 3
# Data 224: Kluster 3
# Data 225: Kluster 3
# Data 226: Kluster 3
# Data 227: Kluster 3
# Data 228: Kluster 3
# Data 229: Kluster 3
# Data 230: Kluster 3
# Data 231: Kluster 3
# Data 232: Kluster 3
# Data 233: Kluster 3
# Data 234: Kluster 3
# Data 235: Kluster 3
# Data 236: Kluster 3
# Data 237: Kluster 3
# Data 238: Kluster 3
# Data 239: Kluster 3
# Data 240: Kluster 3
# Data 241: Kluster 3
# Data 242: Kluster 3
# Data 243: Kluster 3
# Data 244: Kluster 3
# Data 245: Kluster 3
# Data 246: Kluster 3
# Data 247: Kluster 3
# Data 248: Kluster 3
# Data 249: Kluster 3
# Data 250: Kluster 3
# Data 251: Kluster 3
# Data 252: Kluster 3
# Data 253: Kluster 3
# Data 254: Kluster 3
# Data 255: Kluster 3
# Data 256: Kluster 3
# Data 257: Kluster 3
# Data 258: Kluster 3
# Data 259: Kluster 3
# Data 260: Kluster 3
# Data 261: Kluster 3
# Data 262: Kluster 3
# Data 263: Kluster 3
# Data 264: Kluster 3
# Data 265: Kluster 3
# Data 266: Kluster 3
# Data 267: Kluster 3
# Data 268: Kluster 3
# Data 269: Kluster 3
# Data 270: Kluster 3
# Data 271: Kluster 3
# Data 272: Kluster 3
# Data 273: Kluster 3
# Data 274: Kluster 3
# Data 275: Kluster 3
# Data 276: Kluster 3
# Data 395: Kluster 3
# Data 396: Kluster 3
# Data 397: Kluster 3
# Data 398: Kluster 3
# Data 399: Kluster 3
# Data 400: Kluster 3
# Data 401: Kluster 1
# Data 402: Kluster 1
# Data 403: Kluster 1
# Data 404: Kluster 1
# Data 405: Kluster 1
# Data 406: Kluster 1
# Data 407: Kluster 1
# Data 408: Kluster 1
# Data 409: Kluster 1
# Data 410: Kluster 1
# Data 411: Kluster 1
# Data 412: Kluster 1
# Data 413: Kluster 1
# Data 414: Kluster 1
# Data 415: Kluster 1
# Data 416: Kluster 3
# Data 417: Kluster 3
# Data 418: Kluster 3
# Data 419: Kluster 3
# Data 420: Kluster 1
# Data 421: Kluster 1
# Data 422: Kluster 1
# Data 423: Kluster 1
# Data 424: Kluster 1
# Data 425: Kluster 3
# Data 426: Kluster 1
# Data 427: Kluster 1
# Data 428: Kluster 3
# Data 429: Kluster 3
# Data 430: Kluster 1
# Data 431: Kluster 1
# Data 432: Kluster 1
# Data 433: Kluster 1
# Data 434: Kluster 1
# Data 435: Kluster 1
# Data 436: Kluster 3
# Data 437: Kluster 3
# Data 438: Kluster 3
# Data 439: Kluster 3
# Data 440: Kluster 3
# Data 441: Kluster 3
# Data 442: Kluster 3
# Data 443: Kluster 1
# Data 444: Kluster 1
# Data 445: Kluster 3
# Data 446: Kluster 1
# Data 447: Kluster 1
# Data 448: Kluster 1
# Data 449: Kluster 1
# Data 450: Kluster 3
# Data 451: Kluster 1
# Data 452: Kluster 3
# Data 453: Kluster 1
# Data 454: Kluster 1
# Data 455: Kluster 1
# Data 456: Kluster 3
# Data 457: Kluster 3
# Data 458: Kluster 1
# Data 459: Kluster 3
# Data 460: Kluster 3
# Data 461: Kluster 1
# Data 462: Kluster 1
# Data 463: Kluster 1
# Data 464: Kluster 1
# Data 465: Kluster 1
# Data 466: Kluster 1
# Data 467: Kluster 1
# Data 468: Kluster 1
# Data 469: Kluster 1
# Data 470: Kluster 1
# Data 471: Kluster 1
# Data 472: Kluster 1
# Data 473: Kluster 1
# Data 474: Kluster 1
# Data 475: Kluster 3
# Data 476: Kluster 1
# Data 477: Kluster 3
# Data 478: Kluster 1
# Data 479: Kluster 1
# Data 480: Kluster 3
# Data 481: Kluster 1
# Data 482: Kluster 3
# Data 483: Kluster 3
# Data 484: Kluster 1
# Data 485: Kluster 1
# Data 486: Kluster 1
# Data 487: Kluster 1
# Data 488: Kluster 3
# Data 489: Kluster 1
# Data 490: Kluster 1
# Data 491: Kluster 1
# Data 492: Kluster 1
# Data 493: Kluster 1
# Data 494: Kluster 1
# Data 495: Kluster 1
# Data 496: Kluster 1
# Data 497: Kluster 1
# Data 498: Kluster 1
# Data 499: Kluster 1
# Data 500: Kluster 1
# Data 501: Kluster 1
# Data 502: Kluster 1
# Data 503: Kluster 1
# Data 504: Kluster 1
# Data 505: Kluster 1
# Data 506: Kluster 1
# Data 507: Kluster 1
# Data 508: Kluster 1
# Data 509: Kluster 1
# Data 510: Kluster 1
# Data 511: Kluster 1
# Data 512: Kluster 1
# Data 513: Kluster 1
# Data 514: Kluster 1
# Data 515: Kluster 1
# Data 516: Kluster 1
# Data 517: Kluster 1
# Data 518: Kluster 1
# Data 519: Kluster 1
# Data 520: Kluster 1
# Data 521: Kluster 1
# Data 522: Kluster 1
# Data 523: Kluster 1
# Data 524: Kluster 1
# Data 525: Kluster 1
# Data 526: Kluster 1
# Data 527: Kluster 1
# Data 528: Kluster 1
# Data 529: Kluster 1
# Data 530: Kluster 1
# Data 531: Kluster 1
# Data 532: Kluster 1
# Data 533: Kluster 1
# Data 534: Kluster 1
# Data 535: Kluster 1
# Data 536: Kluster 1
# Data 537: Kluster 1
# Data 538: Kluster 1
# Data 539: Kluster 1
# Data 540: Kluster 1
# Data 541: Kluster 1
# Data 542: Kluster 1
# Data 543: Kluster 1
# Data 544: Kluster 1
# Data 545: Kluster 1
# Data 546: Kluster 1
# Data 547: Kluster 1
# Data 548: Kluster 1
# Data 549: Kluster 1
# Data 550: Kluster 1
# Data 551: Kluster 1
# Data 552: Kluster 1
# Data 553: Kluster 1
# Data 554: Kluster 1
# Data 555: Kluster 1
# Data 556: Kluster 1
# Data 557: Kluster 1
# Data 558: Kluster 1
# Data 559: Kluster 1
# Data 560: Kluster 1
# Data 561: Kluster 1
# Data 562: Kluster 1
# Data 563: Kluster 1
# Data 564: Kluster 1
# Data 565: Kluster 1
# Data 566: Kluster 1
# Data 567: Kluster 1
# Data 568: Kluster 1
# Data 569: Kluster 1
# Data 570: Kluster 1
# Data 571: Kluster 1
# Data 572: Kluster 1
# Data 573: Kluster 1
# Data 574: Kluster 1
# Data 575: Kluster 1
# Data 576: Kluster 1
# Data 577: Kluster 1
# Data 578: Kluster 1
# Data 579: Kluster 1
# Data 580: Kluster 1
# Data 581: Kluster 1
# Data 582: Kluster 1
# Data 583: Kluster 1
# Data 584: Kluster 1
# Data 585: Kluster 1
# Data 586: Kluster 1
# Data 587: Kluster 1
# Data 588: Kluster 1
# Data 589: Kluster 1
# Data 590: Kluster 1
# Data 591: Kluster 1
# Data 592: Kluster 1
# Data 593: Kluster 1
# Data 594: Kluster 1
# Data 595: Kluster 1
# Data 596: Kluster 1
# Data 597: Kluster 1
# Data 598: Kluster 1
# Data 599: Kluster 1
# Data 600: Kluster 1
# Data 601: Kluster 2
# Data 602: Kluster 2
# Data 603: Kluster 2
# Data 604: Kluster 2
# Data 605: Kluster 2
# Data 606: Kluster 2
# Data 607: Kluster 2
# Data 608: Kluster 2
# Data 609: Kluster 2
# Data 610: Kluster 2
# Data 611: Kluster 2
# Data 612: Kluster 2
# Data 613: Kluster 2
# Data 614: Kluster 2
# Data 615: Kluster 2
# Data 616: Kluster 2
# Data 617: Kluster 2
# Data 618: Kluster 2
# Data 619: Kluster 2
# Data 620: Kluster 2
# Data 621: Kluster 2
# Data 622: Kluster 2
# Data 623: Kluster 2
# Data 624: Kluster 2
# Data 625: Kluster 2
# Data 626: Kluster 2
# Data 627: Kluster 2
# Data 628: Kluster 2
# Data 629: Kluster 2
# Data 630: Kluster 2
# Data 631: Kluster 2
# Data 632: Kluster 2
# Data 633: Kluster 2
# Data 634: Kluster 2
# Data 635: Kluster 2
# Data 636: Kluster 2
# Data 637: Kluster 2
# Data 638: Kluster 2
# Data 639: Kluster 2
# Data 640: Kluster 2
# Data 641: Kluster 2
# Data 642: Kluster 2
# Data 643: Kluster 2
# Data 644: Kluster 2
# Data 645: Kluster 2
# Data 646: Kluster 2
# Data 647: Kluster 2
# Data 648: Kluster 2
# Data 649: Kluster 2
# Data 650: Kluster 2
# Data 651: Kluster 2
# Data 652: Kluster 2
# Data 653: Kluster 2
# Data 654: Kluster 2
# Data 655: Kluster 2
# Data 656: Kluster 2
# Data 657: Kluster 2
# Data 658: Kluster 2
# Data 659: Kluster 2
# Data 660: Kluster 2
# Data 661: Kluster 2
# Data 662: Kluster 2
# Data 663: Kluster 2
# Data 664: Kluster 2
# Data 665: Kluster 2
# Data 666: Kluster 2
# Data 667: Kluster 2
# Data 668: Kluster 2
# Data 669: Kluster 2
# Data 670: Kluster 2
# Data 671: Kluster 2
# Data 672: Kluster 2
# Data 673: Kluster 2
# Data 674: Kluster 2
# Data 675: Kluster 2
# Data 676: Kluster 2
# Data 677: Kluster 2
# Data 678: Kluster 2
# Data 679: Kluster 2
# Data 680: Kluster 2
# Data 681: Kluster 2
# Data 682: Kluster 2
# Data 683: Kluster 2
# Data 684: Kluster 2
# Data 685: Kluster 2
# Data 686: Kluster 2
# Data 687: Kluster 2
# Data 688: Kluster 2
# Data 689: Kluster 2
# Data 690: Kluster 2
# Data 691: Kluster 2
# Data 692: Kluster 2
# Data 693: Kluster 2
# Data 694: Kluster 2
# Data 695: Kluster 2
# Data 696: Kluster 2
# Data 697: Kluster 2
# Data 698: Kluster 2
# Data 699: Kluster 2
# Data 700: Kluster 2
# Data 701: Kluster 1
# Data 702: Kluster 1
# Data 703: Kluster 1
# Data 704: Kluster 1
# Data 705: Kluster 1
# Data 706: Kluster 1
# Data 707: Kluster 1
# Data 708: Kluster 1
# Data 709: Kluster 1
# Data 710: Kluster 1
# Data 711: Kluster 1
# Data 712: Kluster 1
# Data 713: Kluster 1
# Data 714: Kluster 1
# Data 715: Kluster 1
# Data 716: Kluster 1
# Data 717: Kluster 1
# Data 718: Kluster 1
# Data 719: Kluster 1
# Data 720: Kluster 1
# Data 721: Kluster 1
# Data 722: Kluster 1
# Data 723: Kluster 1
# Data 724: Kluster 1
# Data 725: Kluster 1
# Data 726: Kluster 1
# Data 727: Kluster 1
# Data 728: Kluster 1
# Data 729: Kluster 1
# Data 730: Kluster 1
# Data 731: Kluster 1
# Data 732: Kluster 1
# Data 733: Kluster 1
# Data 734: Kluster 1
# Data 735: Kluster 1
# Data 736: Kluster 1
# Data 737: Kluster 1
# Data 738: Kluster 1
# Data 739: Kluster 1
# Data 740: Kluster 1
# Data 741: Kluster 1
# Data 742: Kluster 1
# Data 743: Kluster 1
# Data 744: Kluster 1
# Data 745: Kluster 1
# Data 746: Kluster 1
# Data 747: Kluster 1
# Data 748: Kluster 1
# Data 749: Kluster 1
# Data 750: Kluster 1
# Data 751: Kluster 1
# Data 752: Kluster 1
# Data 753: Kluster 1
# Data 754: Kluster 1
# Data 755: Kluster 1
# Data 756: Kluster 1
# Data 757: Kluster 1
# Data 758: Kluster 1
# Data 759: Kluster 1
# Data 760: Kluster 1
# Data 761: Kluster 1
# Data 762: Kluster 1
# Data 763: Kluster 1
# Data 764: Kluster 1
# Data 765: Kluster 1
# Data 766: Kluster 1
# Data 767: Kluster 1
# Data 768: Kluster 1
# Data 769: Kluster 1
# Data 770: Kluster 1
# Data 771: Kluster 1
# Data 772: Kluster 1
# Data 773: Kluster 1
# Data 774: Kluster 1
# Data 775: Kluster 1
# Data 776: Kluster 1
# Data 777: Kluster 1
# Data 778: Kluster 1
# Data 779: Kluster 1
# Data 780: Kluster 1
# Data 781: Kluster 1
# Data 782: Kluster 1
# Data 783: Kluster 1
# Data 784: Kluster 1
# Data 785: Kluster 1
# Data 786: Kluster 1
# Data 787: Kluster 1
# Data 788: Kluster 1
# Data 789: Kluster 1
# Data 790: Kluster 1
# Data 791: Kluster 1
# Data 792: Kluster 1
# Data 793: Kluster 1
# Data 794: Kluster 1
# Data 795: Kluster 1
# Data 796: Kluster 1
# Data 797: Kluster 1
# Data 798: Kluster 1
# Data 799: Kluster 1
# Data 800: Kluster 1
# Data 801: Kluster 1
# Data 802: Kluster 1
# Data 803: Kluster 1
# Data 804: Kluster 1
# Data 805: Kluster 1
# Data 806: Kluster 1
# Data 807: Kluster 1
# Data 808: Kluster 1
# Data 809: Kluster 1
# Data 810: Kluster 1
# Data 811: Kluster 1
# Data 812: Kluster 1
# Data 813: Kluster 1
# Data 814: Kluster 1
# Data 815: Kluster 1
# Data 816: Kluster 1
# Data 817: Kluster 1
# Data 818: Kluster 1
# Data 819: Kluster 1
# Data 820: Kluster 1
# Data 821: Kluster 1
# Data 822: Kluster 1
# Data 823: Kluster 1
# Data 824: Kluster 1
# Data 825: Kluster 1
# Data 826: Kluster 1
# Data 827: Kluster 1
# Data 828: Kluster 1
# Data 829: Kluster 1
# Data 830: Kluster 1
# Data 831: Kluster 1
# Data 832: Kluster 1
# Data 833: Kluster 1
# Data 834: Kluster 1
# Data 835: Kluster 1
# Data 836: Kluster 1
# Data 837: Kluster 1
# Data 838: Kluster 1
# Data 839: Kluster 1
# Data 840: Kluster 1
# Data 841: Kluster 1
# Data 842: Kluster 1
# Data 843: Kluster 1
# Data 844: Kluster 1
# Data 845: Kluster 1
# Data 846: Kluster 1
# Data 847: Kluster 1
# Data 848: Kluster 1
# Data 849: Kluster 1
# Data 850: Kluster 1
# Data 851: Kluster 1
# Data 852: Kluster 1
# Data 853: Kluster 1
# Data 854: Kluster 1
# Data 855: Kluster 1
# Data 856: Kluster 1
# Data 857: Kluster 1
# Data 858: Kluster 1
# Data 859: Kluster 1
# Data 860: Kluster 1
# Data 861: Kluster 1
# Data 862: Kluster 1
# Data 863: Kluster 1
# Data 864: Kluster 1
# Data 865: Kluster 1
# Data 866: Kluster 1
# Data 867: Kluster 1
# Data 868: Kluster 1
# Data 869: Kluster 1
# Data 870: Kluster 1
# Data 871: Kluster 1
# Data 872: Kluster 1
# Data 873: Kluster 1
# Data 874: Kluster 1
# Data 875: Kluster 1
# Data 876: Kluster 1
# Data 877: Kluster 1
# Data 878: Kluster 1
# Data 879: Kluster 1
# Data 880: Kluster 1
# Data 881: Kluster 1
# Data 882: Kluster 1
# Data 883: Kluster 1
# Data 884: Kluster 1
# Data 885: Kluster 1
# Data 886: Kluster 1
# Data 887: Kluster 1
# Data 888: Kluster 1
# Data 889: Kluster 1
# Data 890: Kluster 1
# Data 891: Kluster 1
# Data 892: Kluster 1
# Data 893: Kluster 1
# Data 894: Kluster 1
# Data 895: Kluster 1
# Data 896: Kluster 1
# Data 897: Kluster 1
# Data 898: Kluster 1
# Data 899: Kluster 1
# Data 900: Kluster 1
# Data 901: Kluster 2
# Data 902: Kluster 2
# Data 903: Kluster 2
# Data 904: Kluster 2
# Data 905: Kluster 2
# Data 906: Kluster 2
# Data 907: Kluster 2
# Data 908: Kluster 2
# Data 909: Kluster 2
# Data 910: Kluster 2
# Data 911: Kluster 2
# Data 912: Kluster 2
# Data 913: Kluster 2
# Data 914: Kluster 2
# Data 915: Kluster 2
# Data 916: Kluster 2
# Data 917: Kluster 2
# Data 918: Kluster 2
# Data 919: Kluster 2
# Data 920: Kluster 2
# Data 921: Kluster 2
# Data 922: Kluster 2
# Data 923: Kluster 2
# Data 924: Kluster 2
# Data 925: Kluster 2
# Data 926: Kluster 2
# Data 927: Kluster 2
# Data 928: Kluster 2
# Data 929: Kluster 2
# Data 930: Kluster 2
# Data 931: Kluster 2
# Data 932: Kluster 2
# Data 933: Kluster 2
# Data 934: Kluster 2
# Data 935: Kluster 2
# Data 936: Kluster 2
# Data 937: Kluster 2
# Data 938: Kluster 2
# Data 939: Kluster 2
# Data 940: Kluster 2
# Data 941: Kluster 2
# Data 942: Kluster 2
# Data 943: Kluster 2
# Data 944: Kluster 2
# Data 945: Kluster 2
# Data 946: Kluster 2
# Data 947: Kluster 2
# Data 948: Kluster 2
# Data 949: Kluster 2
# Data 950: Kluster 2
# Data 951: Kluster 2
# Data 952: Kluster 2
# Data 953: Kluster 2
# Data 954: Kluster 2
# Data 955: Kluster 2
# Data 956: Kluster 2
# Data 957: Kluster 2
# Data 958: Kluster 2
# Data 959: Kluster 2
# Data 960: Kluster 2
# Data 961: Kluster 2
# Data 962: Kluster 2
# Data 963: Kluster 2
# Data 964: Kluster 2
# Data 965: Kluster 2
# Data 966: Kluster 2
# Data 967: Kluster 2
# Data 968: Kluster 2
# Data 969: Kluster 2
# Data 970: Kluster 2
# Data 971: Kluster 2
# Data 972: Kluster 2
# Data 973: Kluster 2
# Data 974: Kluster 2
# Data 975: Kluster 2
# Data 976: Kluster 2
# Data 977: Kluster 2
# Data 978: Kluster 2
# Data 979: Kluster 2
# Data 980: Kluster 2
# Data 981: Kluster 2
# Data 982: Kluster 2
# Data 983: Kluster 2
# Data 984: Kluster 2
# Data 985: Kluster 2
# Data 986: Kluster 2
# Data 987: Kluster 2
# Data 1868: Kluster 2
# Data 1869: Kluster 2
# Data 1870: Kluster 2
# Data 1871: Kluster 2
# Data 1872: Kluster 2
# Data 1873: Kluster 2
# Data 1874: Kluster 2
# Data 1875: Kluster 2
# Data 1876: Kluster 2
# Data 1877: Kluster 2
# Data 1878: Kluster 2
# Data 1879: Kluster 2
# Data 1880: Kluster 2
# Data 1881: Kluster 2
# Data 1882: Kluster 2
# Data 1883: Kluster 2
# Data 1884: Kluster 2
# Data 1885: Kluster 2
# Data 1886: Kluster 2
# Data 1887: Kluster 2
# Data 1888: Kluster 2
# Data 1889: Kluster 2
# Data 1890: Kluster 2
# Data 1891: Kluster 2
# Data 1892: Kluster 2
# Data 1893: Kluster 2
# Data 1894: Kluster 2
# Data 1895: Kluster 2
# Data 1896: Kluster 2
# Data 1897: Kluster 2
# Data 1898: Kluster 2
# Data 1899: Kluster 2
# Data 1900: Kluster 2
# Data 1901: Kluster 2
# Data 1902: Kluster 2
# Data 1903: Kluster 2
# Data 1904: Kluster 2
# Data 1905: Kluster 2
# Data 1906: Kluster 2
# Data 1907: Kluster 2
# Data 1908: Kluster 2
# Data 1909: Kluster 2
# Data 1910: Kluster 2
# Data 1911: Kluster 2
# Data 1912: Kluster 2
# Data 1913: Kluster 2
# Data 1914: Kluster 2
# Data 1915: Kluster 2
# Data 1916: Kluster 2
# Data 1917: Kluster 2
# Data 1918: Kluster 2
# Data 1919: Kluster 2
# Data 1920: Kluster 2
# Data 1921: Kluster 2
# Data 1922: Kluster 2
# Data 1923: Kluster 2
# Data 1924: Kluster 2
# Data 1925: Kluster 1
# Data 1926: Kluster 1
# Data 1927: Kluster 1
# Data 1928: Kluster 1
# Data 1929: Kluster 1
# Data 1930: Kluster 1
# Data 1931: Kluster 1
# Data 1932: Kluster 1
# Data 1933: Kluster 1
# Data 1934: Kluster 1
# Data 1935: Kluster 1
# Data 1936: Kluster 1
# Data 1937: Kluster 1
# Data 1938: Kluster 1
# Data 1939: Kluster 1
# Data 1940: Kluster 1
# Data 1941: Kluster 1
# Data 1942: Kluster 1
# Data 1943: Kluster 1
# Data 1944: Kluster 1
# Data 1945: Kluster 1
# Data 1946: Kluster 1
# Data 1947: Kluster 1
# Data 1948: Kluster 1
# Data 1949: Kluster 1
# Data 1950: Kluster 1
# Data 1951: Kluster 1
# Data 1952: Kluster 1
# Data 1953: Kluster 1
# Data 1954: Kluster 1
# Data 1955: Kluster 1
# Data 1956: Kluster 1
# Data 1957: Kluster 1
# Data 1958: Kluster 1
# Data 1959: Kluster 1
# Data 1960: Kluster 1
# Data 1961: Kluster 1
# Data 1962: Kluster 1
# Data 1963: Kluster 1
# Data 1964: Kluster 1
# Data 1965: Kluster 1
# Data 1966: Kluster 1
# Data 1967: Kluster 1
# Data 1968: Kluster 1
# Data 1969: Kluster 1
# Data 1970: Kluster 1
# Data 1971: Kluster 1
# Data 1972: Kluster 1
# Data 1973: Kluster 1
# Data 1974: Kluster 1
# Data 1975: Kluster 1
# Data 1976: Kluster 1
# Data 1977: Kluster 1
# Data 2088: Kluster 2
# Data 2089: Kluster 2
# Data 2090: Kluster 2
# Data 2091: Kluster 2
# Data 2092: Kluster 2
# Data 2093: Kluster 2
# Data 2094: Kluster 2
# Data 2095: Kluster 2
# Data 2096: Kluster 2
# Data 2097: Kluster 2
# Data 2098: Kluster 2
# Data 2099: Kluster 2
# Data 2100: Kluster 2

# %%
kmeans.cluster_centers_
# Out:
# array([[27.61052632, 59.14285714],
#        [26.11092715, 87.83278146],
#        [20.96035242, 21.57709251]])

# %%
inertia = kmeans.inertia_
print("Inertia:", inertia)
# Out:
# Inertia: 124324.95655597564

# %%
df_resampled['label'] = y_res

# %%
import matplotlib.pyplot as plt

# Fit k-Means on the dataset
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_res)

# Get the predicted cluster labels
y_kmeans = kmeans.predict(X_res)

# Create a scatter plot
plt.scatter(X_res[y_kmeans == 0]['temperature'], X_res[y_kmeans == 0]['humidity'], c='red', label='Cluster 0')
plt.scatter(X_res[y_kmeans == 1]['temperature'], X_res[y_kmeans == 1]['humidity'], c='blue', label='Cluster 1')
plt.scatter(X_res[y_kmeans == 2]['temperature'], X_res[y_kmeans == 2]['humidity'], c='green', label='Cluster 2')
# Add code above based on the number of clusters produced

# Plot the centroids
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='black', label='Centroids')

# Add labels to the x and y axes
plt.xlabel('Temperature')
plt.ylabel('Humidity')

# Add a legend
plt.legend()

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import pandas as pd

# Create a new dataframe with the cluster labels
df_clusters = df_resampled.copy()
df_clusters['cluster'] = y_kmeans

# Create separate dataframes for each cluster
cluster_dfs = {}
for cluster_label in range(kmeans.n_clusters):
    cluster_dfs[cluster_label] = df_clusters[df_clusters['cluster'] == cluster_label].drop('cluster', axis=1)

# Print the labels in each cluster
for cluster_label, cluster_df in cluster_dfs.items():
    print(f"Cluster {cluster_label}:")
    labels = cluster_df['label'].unique()
    print("Labels:", labels)
    print("=============================")
# Out:
# Cluster 0:
# Labels: ['jagung' 'kacang polong' 'kacang panjang' 'lentil hitam' 'lentil'
#  'mangga' 'kopi']
# =============================
# Cluster 1:
# Labels: ['padi' 'jagung' 'kacang hijau' 'delima' 'pisang' 'anggur' 'semangka'
#  'melon' 'apel' 'jeruk' 'pepaya' 'kelapa' 'kapas']
# =============================
# Cluster 2:
# Labels: ['buncis' 'kacang merah' 'kacang polong']
# =============================

# %%
import matplotlib.pyplot as plt

# Create a new dataframe with the cluster labels
df_clusters = df_resampled.copy()
df_clusters['cluster'] = y_kmeans

# Create a bar plot to show the distribution of labels in each cluster
cluster_counts = df_clusters.groupby(['cluster', 'label']).size().unstack()
cluster_counts.plot(kind='bar', stacked=True)

# Set the plot title and labels
plt.title('Label Distribution in Each Cluster')
plt.xlabel('Cluster')
plt.ylabel('Count')


# Set the width of the figure
fig = plt.gcf()
fig.set_size_inches(12, 6)  # Adjust the width and height as needed


# Show the plot
plt.show()

# %%
# Export each cluster to a separate dataframe
for cluster_label in df_clusters['cluster'].unique():
    cluster_df = df_clusters[df_clusters['cluster'] == cluster_label]
    cluster_df.to_csv(f'cluster_{cluster_label}.csv', index=False)
